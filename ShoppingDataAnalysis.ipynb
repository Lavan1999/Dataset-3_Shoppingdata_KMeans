# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavan1999/100-Dataset-6---Shopping-Dataset-/blob/main/ShoppingDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("/content/Shopping_data.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
'''
1---Unsupervised Data


2--- Category Column - "Genre"
 --- Continuous column - "CustomerID", "Annual Income (k$)", "Spending Score (1-100)","Age"

3---Correlation Test for Numerical columns

4--- Hypothesis testing: continuous Vs continuous
      customerid-annual income
      customerid-spendingscore
      customerid-age
      annualincome-spendingscore
      annualincome-age
      spendingscore-age
5---Hypothesis testing for category VS continous
      genre vs customerid
      genre vs annual income
      genre vs spending score
      genre vs age

# %%
'''
Correlation Test for Numerical Columns
By the result of correlation Test,
No related columns -    customer id with age,
                        customer id with spending score,
                        annual income with age,
                        spending score with annual income

Related columns - costomer id and annual income,
                    age and spending score'''

# %%
df.corr()
# Out:
# <ipython-input-24-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
'''customerid-annual income
                                   customerid-annual income
                                   customerid-spendingscore
                                   customerid-age
                                   annualincome-spendingscore
                                   annualincome-age
                                   spendingscore-age '''

# %%
#Hypothesis Testing

#1-Two sample ttest for CustomerID VS spendinscore

for i in range(25):
  sample1 = df.CustomerID.sample(frac=0.05)
  sample2 = df["Spending Score (1-100)"].sample(frac=0.04)

  t_test, p_value = stats.ttest_ind(sample1,sample2)
  if p_value > 0.05:
    print("H0 null hypothesis accepted and Ha alternative hypothesis rejected")
  else:
    print("H0 null hypothesis rejected and Ha alternative hypothesis accepted")

# Here I got 13 acceptance and 12 rejection so that Null hypothesis is accepted by the majaricy results
# Out:
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# ...

# %%
#Hypothesis Testing

#1-Two sample ttest for CustomerID VS age

for i in range(25):
  sample1 = df.CustomerID.sample(frac=0.05)
  sample2 = df["Age"].sample(frac=0.04)

  t_test, p_value = stats.ttest_ind(sample1,sample2)
  if p_value > 0.05:
    print("H0 null hypothesis accepted and Ha alternative hypothesis rejected")
  else:
    print("H0 null hypothesis rejected and Ha alternative hypothesis accepted")

# Here I got 7 acceptance and 15 rejection so that Null hypothesis is rejected by the majaricy results
# Out:
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# ...

# %%
#Hypothesis Testing

#1-Two sample ttest for CustomerID VS annual income

for i in range(25):
  sample1 = df.CustomerID.sample(frac=0.05)
  sample2 = df["Annual Income (k$)"].sample(frac=0.04)

  t_test, p_value = stats.ttest_ind(sample1,sample2)
  if p_value > 0.05:
    print("H0 null hypothesis accepted and Ha alternative hypothesis rejected")
  else:
    print("H0 null hypothesis rejected and Ha alternative hypothesis accepted")

# Here I got 13 acceptance and 12 rejection so that Null hypothesis is accepted by the majaricy results
# Out:
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# ...

# %%
#Hypothesis Testing

#1-Two sample ttest for annual income VS spendinscore

for i in range(25):
  sample1 = df["Spending Score (1-100)"].sample(frac=0.05)
  sample2 = df["Annual Income (k$)"].sample(frac=0.04)

  t_test, p_value = stats.ttest_ind(sample1,sample2)
  if p_value > 0.05:
    print("H0 null hypothesis accepted and Ha alternative hypothesis rejected")
  else:
    print("H0 null hypothesis rejected and Ha alternative hypothesis accepted")

# Here I got 23 acceptance and 2 rejection so that Null hypothesis is accepted by the majaricy results
# Out:
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# ...

# %%
#Hypothesis Testing

#1-Two sample ttest for annualincome - age

for i in range(25):
  sample1 = df["Age"].sample(frac=0.05)
  sample2 = df["Annual Income (k$)"].sample(frac=0.04)

  t_test, p_value = stats.ttest_ind(sample1,sample2)
  if p_value > 0.05:
    print("H0 null hypothesis accepted and Ha alternative hypothesis rejected")
  else:
    print("H0 null hypothesis rejected and Ha alternative hypothesis accepted")

# Here I got 10 acceptance and 15 rejection so that Null hypothesis is rejected by the majaricy results
# Out:
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# ...

# %%
#Hypothesis Testing

#1-Two sample ttest for annual age VS spendinscore

for i in range(25):
  sample1 = df["Spending Score (1-100)"].sample(frac=0.05)
  sample2 = df["Age"].sample(frac=0.04)

  t_test, p_value = stats.ttest_ind(sample1,sample2)
  if p_value > 0.05:
    print("H0 null hypothesis accepted and Ha alternative hypothesis rejected")
  else:
    print("H0 null hypothesis rejected and Ha alternative hypothesis accepted")

# Here I got 20 acceptance and 5 rejection so that Null hypothesis is accepted by the majaricy results
# Out:
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# H0 null hypothesis accepted and Ha alternative hypothesis rejected
# H0 null hypothesis rejected and Ha alternative hypothesis accepted
# ...

# %%
# f-Test for continuous vs category

group = df['Genre'].unique()
data = {}
for i in group:
  data[i]=df["Annual Income (k$)"][df["Genre"]==i]


f_value, p_value = stats.f_oneway(data['Male'],data['Female']
                                  )
print(f_value, p_value)
if p_value<0.05:
  print("H0 - Null hypothesis is rejected which means no relationship exists")
else:
  print("Ha - Null hypothesis is accepted which means relationship exists")
#Result --Ha - Null hypothesis is accepted which means relationship exists
# Out:
# 0.6320604552747227 0.4275524939992865
# Ha - Null hypothesis is accepted which means relationship exists

# %%
# f-Test for continuous vs category

group = df['Genre'].unique()
data = {}
for i in group:
  data[i]=df["Age"][df["Genre"]==i]


f_value, p_value = stats.f_oneway(data['Male'],data['Female'])

print(f_value, p_value)
if p_value<0.05:
  print("H0 - Null hypothesis is rejected which means no relationship exists")
else:
  print("Ha - Null hypothesis is accepted which means relationship exists")
#Result --Ha - Null hypothesis is accepted which means relationship exists
# Out:
# 0.7362859039559835 0.39189073778826133
# Ha - Null hypothesis is accepted which means relationship exists

# %%
# f-Test for continuous vs category

group = df['Genre'].unique()
data = {}
for i in group:
  data[i]=df["Spending Score (1-100)"][df["Genre"]==i]


f_value, p_value = stats.f_oneway(data['Male'],data['Female'])

print(f_value, p_value)
if p_value<0.05:
  print("H0 - Null hypothesis is rejected which means no relationship exists")
else:
  print("Ha - Null hypothesis is accepted which means relationship exists")
#Result --Ha - Null hypothesis is accepted which means relationship exists
# Out:
# 0.6708370300325192 0.4137446589852207
# Ha - Null hypothesis is accepted which means relationship exists

# %%
# f-Test for continuous vs category

group = df['Genre'].unique()
data = {}
for i in group:
  data[i]=df["CustomerID"][df["Genre"]==i]


f_value, p_value = stats.f_oneway(data['Male'],data['Female'])

print(f_value, p_value)
if p_value<0.05:
  print("H0 - Null hypothesis is rejected which means no relationship exists")
else:
  print("Ha - Null hypothesis is accepted which means relationship exists")
#Result --Ha - Null hypothesis is accepted which means relationship exists
# Out:
# 0.6545180987538248 0.4194730348538205
# Ha - Null hypothesis is accepted which means relationship exists

# %%
#Visualisation:
import plotly.express as px

# %%
fig1 = px.bar(df, x = "Genre", y = "Spending Score (1-100)",
                    color='Genre',hover_name = 'Age',
                    animation_frame='Age')
fig1.update_yaxes(range=[0, 500])
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
